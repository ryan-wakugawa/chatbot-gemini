# %% [markdown]
# # Baking with the Gemini API
#
# To get started, [get an API key](https://g.co/ai/idxGetGeminiKey) and replace the word `TODO` below with your API key:

# %%
API_KEY = 'AIzaSyBB_OVYrnqMPbyL2SxCq9bA5ijtWnkxaN4'

# %% [markdown]
# Once you're done, create a text prompt here:

# %%
prompt = 'Me diga a receita de um mousse de chocolate'

# %% [markdown]
# And load an image with PIL:

# %%
import PIL.Image
# img = PIL.Image.open('baked_goods_1.jpg')
img = PIL.Image.open('baked_goods_2.jpg')
# img = PIL.Image.open('baked_goods_3.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %% [markdown]
# And finally, call the Gemini API using the Python client library. [See the docs](https://developers.generativeai.google/guide)

# %%
import google.generativeai as genai
from IPython.display import Markdown, clear_output, display

genai.configure(api_key=API_KEY)

model = genai.GenerativeModel(model_name='gemini-pro')
response = model.generate_content([prompt], stream=True)

buffer = []
for chunk in response:
    for part in chunk.parts:
        buffer.append(part.text)
    clear_output()
    display(Markdown(''.join(buffer)))
# Out:
# **Ingredientes para o Mousse de Chocolate:**
#
# * 200g de chocolate meio amargo (70% cacau ou mais)
# * 3 ovos grandes, separados
# * 100g de açúcar
# * 1/4 xícara (60ml) de creme de leite fresco
#
# **Instruções:**
#
# 1. **Derreta o chocolate:** Quebre o chocolate em pedaços e derreta-o em banho-maria ou no micro-ondas em intervalos de 30 segundos, mexendo a cada intervalo, até que esteja derretido e homogêneo.
# 2. **Prepare as claras em neve:** Em uma tigela limpa e seca, bata as claras em neve até que atinjam picos firmes.
# 3. **Bata as gemas e o açúcar:** Em outra tigela, bata as gemas com o açúcar até que fiquem claras e espessas.
# 4. **Incorpore as claras em neve:** Adicione 1/3 das claras em neve às gemas batidas e misture delicadamente para incorporar. Em seguida, adicione o restante das claras em neve e misture até que esteja uniformemente incorporado.
# 5. **Adicione o chocolate derretido:** Despeje o chocolate derretido sobre a mistura de gemas e claras e misture delicadamente até que esteja totalmente incorporado.
# 6. **Bata o creme de leite:** Em uma tigela separada, bata o creme de leite fresco até que atinja picos firmes.
# 7. **Incorpore o creme de leite:** Adicione metade do creme de leite batido à mistura de chocolate e misture delicadamente para incorporar. Em seguida, adicione o restante do creme de leite batido e misture até que esteja uniformemente incorporado.
# 8. **Resfrie:** Despeje o mousse em tigelas ou copos individuais e refrigere por pelo menos 4 horas antes de servir.
#
# **Dicas:**
#
# * Para um mousse mais rico, use chocolate com maior teor de cacau.
# * Para um mousse mais arejado, bata as claras em neve por mais tempo até que fiquem bem firmes.
# * Sirva o mousse gelado com suas coberturas favoritas, como frutas frescas, chantilly ou biscoitos triturados.
